# %% [markdown]
# # Algin Dataset
# ## LLaVA-CC3M-Pretrain-595K

# %%
# !git clone https://huggingface.co/datasets/liuhaotian/LLaVA-CC3M-Pretrain-595K

# %%
# !unzip LLaVA-CC3M-Pretrain-595K/images.zip -d LLaVA-CC3M-Pretrain-595K/images/

# %% [markdown]
# # conversation 客製化製作

# %%
from conversations import conversations, load_data

path = "LLaVA-CC3M-Pretrain-595K/chat.json"
data = load_data(path)

print(f"Loaded {len(data)} records from {path}")
print("Sample record:", data[0])
# Out:
# Loaded 595375 records from LLaVA-CC3M-Pretrain-595K/chat.json
# Sample record: {'id': 'GCC_train_002582585', 'image': 'GCC_train_002582585.jpg', 'conversations': [{'from': 'human', 'value': 'Provide a brief description of the given image.\n'}, {'from': 'gpt', 'value': 'olive oil is a healthy ingredient used liberally .'}]}
